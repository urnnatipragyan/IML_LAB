# %%
n = int(input("Enter number of data points: "))
p = int(input("Enter the number of independent variables: "))

X = [[0]*p for _ in range(n)]
y = []

for i in range(n):
    for j in range(p):
        X[i][j] = input(f"Enter the {j+1} independent variable (string) for row {i+1}: ")
    y.append(input(f"Enter target class for row {i+1}: "))

target_classes = list(set(y))

input_point = []
for j in range(p):
    input_point.append(input(f"Enter input value (string) for variable {j+1}: "))

stats = {cls: {'count': 0, 'feature_counts': [{} for _ in range(p)]} for cls in target_classes}

for idx, cls in enumerate(y):
    stats[cls]['count'] += 1
    for j in range(p):
        val = X[idx][j]
        if val not in stats[cls]['feature_counts'][j]:
            stats[cls]['feature_counts'][j][val] = 0
        stats[cls]['feature_counts'][j][val] += 1

posteriors = {}
total_count = n

for cls in target_classes:
    prior = stats[cls]['count'] / total_count
    likelihood = 1
    for j in range(p):
        val = input_point[j]
        count = stats[cls]['feature_counts'][j].get(val, 0) + 1
        total = stats[cls]['count'] + len(stats[cls]['feature_counts'][j])
        likelihood *= count / total
    posteriors[cls] = prior * likelihood

predicted_class = max(posteriors, key=posteriors.get)
print("Predicted target class is:", predicted_class)
# Out:
# Enter number of data points: 8
# Enter the number of independent variables: 4
# Enter the 1 independent variable (string) for row 1: white
# Enter the 2 independent variable (string) for row 1: 3
# Enter the 3 independent variable (string) for row 1: short
# Enter the 4 independent variable (string) for row 1: yes
# Enter target class for row 1: m
# Enter the 1 independent variable (string) for row 2: green
# Enter the 2 independent variable (string) for row 2: 2
# Enter the 3 independent variable (string) for row 2: tall
# Enter the 4 independent variable (string) for row 2: no
# Enter target class for row 2: m
# Enter the 1 independent variable (string) for row 3: green
# Enter the 2 independent variable (string) for row 3: 3
# Enter the 3 independent variable (string) for row 3: short
# Enter the 4 independent variable (string) for row 3: yes
# Enter target class for row 3: m
# Enter the 1 independent variable (string) for row 4: white
# Enter the 2 independent variable (string) for row 4: 3
# Enter the 3 independent variable (string) for row 4: short
# Enter the 4 independent variable (string) for row 4: yes
# Enter target class for row 4: m
# Enter the 1 independent variable (string) for row 5: green
# Enter the 2 independent variable (string) for row 5: 2
# Enter the 3 independent variable (string) for row 5: short
# Enter the 4 independent variable (string) for row 5: no
# Enter target class for row 5: h
# Enter the 1 independent variable (string) for row 6: white
# Enter the 2 independent variable (string) for row 6: 2
# Enter the 3 independent variable (string) for row 6: tall
# Enter the 4 independent variable (string) for row 6: no
# Enter target class for row 6: h
# Enter the 1 independent variable (string) for row 7: white
# Enter the 2 independent variable (string) for row 7: 2
# Enter the 3 independent variable (string) for row 7: tall
# Enter the 4 independent variable (string) for row 7: no
# Enter target class for row 7: h
# Enter the 1 independent variable (string) for row 8: white
# Enter the 2 independent variable (string) for row 8: 2
# Enter the 3 independent variable (string) for row 8: short
# Enter the 4 independent variable (string) for row 8: yes
# Enter target class for row 8: h
# Enter input value (string) for variable 1: green
# Enter input value (string) for variable 2: 2
# Enter input value (string) for variable 3: tall
# Enter input value (string) for variable 4: no
# Predicted target class is: h
